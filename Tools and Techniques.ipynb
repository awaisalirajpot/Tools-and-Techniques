# %% [markdown]
# ## Tools and Techniques by sir Zia

# %% [markdown]
# ### KNN
# k nearest neighbours

# %%
import pandas as pd

# %%
x1 = [1,3,3,4,5,6]
x2 = [3,3,6,2,5,4]
pd.DataFrame(x1,x2)
# Out:
#    0
# 3  1
# 3  3
# 6  3
# 2  4
# 5  5
# 4  6
